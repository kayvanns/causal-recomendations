# %%
# %sql
CREATE SCHEMA IF NOT EXISTS causal_project;


CREATE OR REPLACE TABLE causal_project.bronze_transactions
AS SELECT * FROM default.transactions;

CREATE OR REPLACE TABLE causal_project.bronze_demographics
AS SELECT * FROM default.demographics;

CREATE OR REPLACE TABLE causal_project.bronze_campaigns
AS SELECT * FROM default.campaigns;

CREATE OR REPLACE TABLE causal_project.bronze_campaign_desc
AS SELECT * FROM default.campaign_desc;

CREATE OR REPLACE TABLE causal_project.bronze_coupons
AS SELECT * FROM default.coupons;

CREATE OR REPLACE TABLE causal_project.bronze_coupon_redempt
AS SELECT * FROM default.coupon_redempt;

CREATE OR REPLACE TABLE causal_project.bronze_features
AS SELECT * FROM default.features;

CREATE OR REPLACE TABLE causal_project.bronze_products
AS SELECT * FROM default.products;

# %%
# %sql
USE causal_project;
select * from bronze_transactions Limit 5
